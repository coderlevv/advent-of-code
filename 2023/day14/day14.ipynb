# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("sequence.csv", "r") as f:
    content = f.read()

# %%
seq = [int(n) for n in content.split(",")]

# %%
plt.plot(seq[40:200])

# %%
seq[100:140]
# Out:
# [106335,
#  106351,
#  106362,
#  106379,
#  106391,
#  106399,
#  106401,
#  106392,
#  106389,
#  106375,
#  106349,
#  106333,
#  106336,
#  106337,
#  106350,
#  106370,
#  106389,
#  106405,
#  106397,
#  106390,
#  106374,
#  106350,
#  106332,
#  106337,
#  106336,
#  106351,
#  106369,
#  106390,
#  106404,
#  106398,
#  106389,
#  106375,
#  106349,
#  106333,
#  106336,
#  106337,
#  106350,
#  106370,
#  106389,
#  106405]

# %%
# cycle start = 108
# cycle len = 22
(1000000000-108)%22
# Out:
# 12

# %%
seq[108+12-1]
# Out:
# 106390
